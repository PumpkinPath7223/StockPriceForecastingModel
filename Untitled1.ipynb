# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_error

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
ticker = 'AAPL'
df = yf.download(ticker, '2020-01-01')
# Out:
# /var/folders/c3/__q9lfhx2j72_q63ckgfgmh40000gn/T/ipykernel_23288/2867026071.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, '2020-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.538521   72.598899   71.292311   71.545897  135480400
# 2020-01-03   71.833298   72.594063   71.608692   71.765674  146322800
# 2020-01-06   72.405701   72.444344   70.703034   70.954210  118387200
# 2020-01-07   72.065170   72.671364   71.845392   72.415360  108872000
# 2020-01-08   73.224419   73.526310   71.768094   71.768094  132079200
# ...                ...         ...         ...         ...        ...
# 2025-08-28  232.559998  233.410004  229.339996  230.820007   38074700
# 2025-08-29  232.139999  233.380005  231.369995  232.509995   39418400
# 2025-09-02  229.720001  230.850006  226.970001  229.250000   44075600
# 2025-09-03  238.470001  238.850006  234.360001  237.210007   66427800
# 2025-09-04  239.779999  239.899994  236.740005  238.449997   47504000
#
# [1426 rows x 5 columns]

# %%
df.Close.plot(figsize =(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
scaler = StandardScaler()

df['Close'] = scaler.fit_transform(df['Close'])

# %%
df.Close
# Out:
# Ticker          AAPL
# Date
# 2020-01-02 -1.933308
# 2020-01-03 -1.948992
# 2020-01-06 -1.936262
# 2020-01-07 -1.943835
# 2020-01-08 -1.918053
# ...              ...
# 2025-08-28  1.625652
# 2025-08-29  1.616311
# 2025-09-02  1.562489
# 2025-09-03  1.757093
# 2025-09-04  1.786228
#
# [1426 rows x 1 columns]

# %%
seq_length = 30
data = []

for i in range(len(df) - seq_length):
    data.append(df["Close"].values[i : i + seq_length])
data = np.array(data)

# %%
train_size = int(0.8 * len(data))

x_train = torch.tensor(data[:train_size, :-1, :]).type(torch.Tensor).to(device)
y_train = torch.tensor(data[:train_size, -1, :]).type(torch.Tensor).to(device)
x_test = torch.tensor(data[train_size:, -1, :]).type(torch.Tensor).to(device)
y_test = torch.tensor(data[train_size:, -1, :]).type(torch.Tensor).to(device)

# Reshape input for LSTM: (batch_size, sequence_length, input_size)
# x_train = x_train.unsqueeze(-1)
# x_test = x_test.unsqueeze(-1)

# %%
class PredictionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(PredictionModel, self).__init__()
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim, device=device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim, device=device)
        
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :])
        return out

# %%
model = PredictionModel(input_dim=1, hidden_dim=32, num_layers=2, output_dim=1).to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
num_epochs = 200

for i in range(num_epochs):
    y_train_pred = model(x_train)
    loss = criterion(y_train_pred, y_train)
    
    if i % 25 == 0:
        print(i,loss.item())
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 0.6209517121315002
# 25 0.009413819760084152
# 50 0.0059272232465445995
# 75 0.005257380660623312
# 100 0.004857666790485382
# 125 0.004497716668993235
# 150 0.004175243433564901
# 175 0.0039019465912133455

# %%
model.eval()

# Reshape x_test to match the expected dimensions
# If x_test is a single sample, add batch dimension
if len(x_test.shape) == 2:
    x_test = x_test.unsqueeze(0)  # Add batch dimension
# If x_test has too many dimensions, reshape appropriately
elif len(x_test.shape) > 3:
    # Reshape based on your specific model requirements
    # Example: x_test = x_test.view(batch_size, seq_length, features)
    pass

# Make prediction with proper dimensions
with torch.no_grad():  # Disable gradient calculation for inference
    y_test_pred = model(x_test)
    
    
if isinstance(y_train_pred, torch.Tensor):
    y_train_pred = y_train_pred.detach().cpu().numpy()
    
# For y_test_pred
if isinstance(y_test_pred, torch.Tensor):
    y_test_pred = y_test_pred.detach().cpu().numpy()
    
# For y_train_true
if isinstance(y_train, torch.Tensor):
    y_train_true = y_train.detach().cpu().numpy()
    
# For y_test_true
if isinstance(y_test, torch.Tensor):
    y_test_true = y_test.detach().cpu().numpy()
    
    
y_train_pred_inv = scaler.inverse_transform(y_train_pred)
y_test_pred_inv = scaler.inverse_transform(y_test_pred)
y_train_true_inv = scaler.inverse_transform(y_train_true)
y_test_true_inv = scaler.inverse_transform(y_test_true)

# %%
train_rmse = root_mean_squared_error(y_train[:, 0], y_train_pred[:, 0])
test_rmse = root_mean_squared_error(y_test[:, 0], y_test_pred[:, 0])
print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[248], line 2
#       1 train_rmse = root_mean_squared_error(y_train[:, 0], y_train_pred[:, 0])
# ----> 2 test_rmse = root_mean_squared_error(y_test[:, 0], y_test_pred[:, 0])
#       3 print("Train RMSE:", train_rmse)
#       4 print("Test RMSE:", test_rmse)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
fig = plt.figure(figsize=(12, 10))
gs = fig.add_gridspec(4, 1)

# Actual vs Predicted plot (top 3/4)
ax1 = fig.add_subplot(gs[:3, 0])

ax1.plot(df.iloc[-len(y_test):].index, y_test, label="Actual Price", color="blue")


ax1.plot(df.iloc[-len(y_test):], y_test, label="Predicted Price", color="green")
ax1.legend()
plt.title(f"{ticker} Stock Price Prediction")
plt.xlabel("Date")
plt.ylabel("Price")
ax1 = df.Close.plot(x_compat=True)
# Error plot (bottom 1/4)
ax2 = fig.add_subplot(gs[3, 0])
ax2.axhline(test_rmse, color="blue", linestyle="--", label="RMSE")
ax2.plot(df[-len(y_test):].index, abs(y_test - y_test), label="Prediction Error", color="red")
ax2.legend()
ax2 = df.Close.plot(x_compat=True)

plt.title("Prediction Error")
plt.xlabel("Date")
plt.ylabel("Error")


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...
